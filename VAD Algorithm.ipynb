# %%
#!/usr/bin/env python
# coding: utf-8
from scipy.io import wavfile
import wave
import webrtcvad
import numpy as np
import glob
import os
import wave
from pydub import AudioSegment
import collections
import argparse
from scipy.signal import butter, lfilter

# %%
def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

#음원 주파수 분리
#https://blog.naver.com/tk1404/222450180651
def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

def find_silences(filename):
    global args
    blend_duration = 0.005
    with wave.open(filename) as wav:
        size = wav.getnframes()
        channels = wav.getnchannels()
        sample_width = wav.getsampwidth()
        frame_rate = wav.getframerate()
        max_value = 1 << (8 * sample_width - 1)
        half_blend_frames = int(blend_duration * frame_rate / 2)
        blend_frames = half_blend_frames * 2
        assert size > blend_frames > 0
        square_threshold = max_value ** 2 * 10 ** (args.threshold_level / 10)
        blend_squares = collections.deque()
        blend = 0

        def get_values():
            frames_read = 0
            while frames_read < size:
                frames = wav.readframes(min(0x1000, size - frames_read))
                frames_count = len(frames) // sample_width // channels
                for frame_index in range(frames_count):
                    yield frames[frame_index*channels*sample_width:(frame_index+1)*channels*sample_width]
                frames_read += frames_count

        def get_is_silence(blend):
            results = 0
            frames = get_values()
            for index in range(half_blend_frames):
                frame = next(frames)
                square = 0
                for channel in range(channels):
                    value = int.from_bytes(frame[sample_width*channel:sample_width*channel+sample_width], 'little', signed=True)
                    square += value*value
                blend_squares.append(square)
                blend += square
            for index in range(size-half_blend_frames):
                frame = next(frames)
                square = 0
                for channel in range(channels):
                    value = int.from_bytes(frame[sample_width*channel:sample_width*channel+sample_width], 'little', signed=True)
                    square += value*value
                blend_squares.append(square)
                blend += square
                if index < half_blend_frames:
                    yield blend < square_threshold * channels * (half_blend_frames + index + 1)
                else:
                    result = blend < square_threshold * channels * (blend_frames + 1)
                    if result:
                        results += 1
                    yield result
                    blend -= blend_squares.popleft()
            for index in range(half_blend_frames):
                blend -= blend_squares.popleft()
                yield blend < square_threshold * channels * (blend_frames - index)

        is_silence = get_is_silence(blend)

        def to_regions(iterable):
            iterator = enumerate(iterable)
            while True:
                try:
                    index, value = next(iterator)
                except StopIteration:
                    return
                if value:
                    start = index
                    while True:
                        try:
                            index, value = next(iterator)
                            if not value:
                                yield start, index
                                break
                        except StopIteration:
                            yield start, index+1
                            return

        threshold_frames = int(args.threshold_duration * frame_rate)
        silence_regions = ( (start, end) for start, end in to_regions(is_silence) if end-start >= blend_duration )
        silence_regions = ( (start + (half_blend_frames if start > 0 else 0), end - (half_blend_frames if end < size else 0)) for start, end in silence_regions )
        silence_regions = [ (start, end) for start, end in silence_regions if end-start >= threshold_frames ]
        including_end = len(silence_regions) == 0 or silence_regions[-1][1] == size
        silence_regions = [ (start/frame_rate, end/frame_rate) for start, end in silence_regions ]
        # print(args.save_silence)
        if args.save_silence:
            with wave.open(args.save_silence, 'wb') as out_wav:
                out_wav.setnchannels(channels)
                out_wav.setsampwidth(sample_width)
                out_wav.setframerate(frame_rate)
                for start, end in silence_regions:
                    wav.setpos(start)
                    frames = wav.readframes(end-start)
                    out_wav.writeframes(frames)

    return silence_regions, including_end


def transform_duration(duration):
    global args
    return args.constant + args.sublinear * math.log(duration + 1) + args.linear * duration

def format_offset(offset):
    return '{}:{}:{}'.format(int(offset) // 3600, int(offset) % 3600 // 60, offset % 60)

def closest_frames(duration, frame_rate):
    return int((duration + 1 / frame_rate / 2) // (1 / frame_rate))

def compress_audio(wav, start_frame, end_frame, result_frames):
    # print(start_frame, end_frame, result_frames)
    if result_frames == 0:
        return b''
    elif result_frames == end_frame - start_frame:
        # print("same")
        wav.setpos(start_frame)
        return wav.readframes(result_frames)
    else:
        channels = wav.getnchannels()
        sample_width = wav.getsampwidth()
        frame_width = sample_width*channels
        if result_frames*2 <= end_frame - start_frame:
            left_length = result_frames
            right_length = result_frames
        else:
            left_length = (end_frame - start_frame + 1) // 2
            right_length = end_frame - start_frame - left_length
        crossfade_length = right_length + left_length - result_frames
        crossfade_start = (result_frames - crossfade_length) // 2
        wav.setpos(start_frame)
        left_frames = wav.readframes(left_length)
        wav.setpos(end_frame - right_length)
        right_frames = wav.readframes(right_length)
        result = bytearray(b'\x00'*result_frames*frame_width)
        result[:(left_length-crossfade_length)*frame_width] = left_frames[:-crossfade_length*frame_width]
        result[-(right_length-crossfade_length)*frame_width:] = right_frames[crossfade_length*frame_width:]
        for i in range(crossfade_length):
            r = i / (crossfade_length - 1)
            l = 1 - r
            for channel in range(channels):
                signal_left = int.from_bytes(left_frames[(left_length-crossfade_length+i)*frame_width+channel*sample_width:(left_length-crossfade_length+i)*frame_width+(channel+1)*sample_width], 'little', signed=True)
                signal_right = int.from_bytes(right_frames[i*frame_width+channel*sample_width:i*frame_width+(channel+1)*sample_width], 'little', signed=True)
                result[(left_length-crossfade_length+i)*frame_width+channel*sample_width:(left_length-crossfade_length+i)*frame_width+(channel+1)*sample_width] = int(signal_left*l + signal_right*r).to_bytes(sample_width, 'little', signed=True)
        return result

class Frame(object):
    """Represents a "frame" of audio data."""
    def __init__(self, bytes, timestamp, duration):
        self.bytes = bytes
        self.timestamp = timestamp
        self.duration = duration

def frame_generator(frame_duration_ms, audio, sample_rate):
    frames = []
    n = int(sample_rate * (frame_duration_ms / 1000.0) * 2)
    offset = 0
    timestamp = 0.0
    duration = (float(n) / sample_rate) / 2.0
    while offset + n < len(audio):
        frames.append(Frame(audio[offset:offset + n], timestamp, duration))
        timestamp += duration
        offset += n
    
    return frames

def match_target_amplitude(sound, target_dBFS):
    change_in_dBFS = target_dBFS - sound.dBFS
    return sound.apply_gain(change_in_dBFS)

# %%
#인자값을 받을 수 있는 인스턴스 생성
parser = argparse.ArgumentParser()

#입력받을 인자값 등록
parser.add_argument('-path', type=str, default='files', help='path to video')#files 폴더
parser.add_argument('-threshold-duration', type=float, default=0.2, help='threshold duration in seconds')
parser.add_argument('-check', type=bool, default=True, help='path to text file')
parser.add_argument('-p', type=str, default='results', help='path to video')
parser.add_argument('--threshold-level', type=float, default=-40, help='threshold level in dB')

parser.add_argument('--constant', type=float, default=0, help='duration constant transform value')
parser.add_argument('--sublinear', type=float, default=0, help='duration sublinear transform factor')
parser.add_argument('--linear', type=float, default=0.1, help='duration linear transform factor')
parser.add_argument('--save-silence', type=str, help='filename for saving silence')
parser.add_argument('--recalculate-time-in-description', type=str, help='path to text file')
parser.add_argument('-f')
#입력받은 인자값 args에 저장
args = parser.parse_args()

# %%
if __name__ == '__main__':
    
    dir_path = os.path.join(os.getcwd() ,args.path, '*.wav')
    print(dir_path) #C:\Users\pc\Desktop\5 dreambit silence_vad\vad_remove_silence-main\files\*.wav
    paths = glob.glob(dir_path) #'*.wav' 의 모든 파일 가져오기
    file_num = len(paths)
    
    start_idx = 0
    end_idx = 0
    
    print('Num of file: ', file_num)
    cnt = 0
    
    print('Audio Normalization...')
    if not os.path.isdir('norm'):
        os.mkdir('norm')
    if not os.path.isdir('norm2'):
        os.mkdir('norm2')
        
    for path in paths:
        
        dst = os.path.join(os.getcwd(), 'norm', path.split(args.path)[-1][1:])#그냥 path.split(args.path)   index 같음
        sound = AudioSegment.from_wav(path)#open file
        
        #normalized_sound = match_target_amplitude(sound, -35.0) #위 def 참고 
        
        normalized_sound=sound #정규화 안 한 코드 
        
        #https://pythonq.com/so/python/839366 위 코드들 볼륨 정상화 하는 코드이다.
       
        #진폭이 평균이 되게 하기 위해서 하는 것 이다.이 결과로 norm 에 데이터 생성됨
        normalized_sound.export(dst, format="wav")
        
        #sound.export(dst, format="wav")
        
        dst2 = os.path.join(os.getcwd(), 'norm2', path.split(args.path)[-1][1:])
        
        sample_rate, samples = wavfile.read(dst)
        
        #sample_rate 는 16000 !!!!
        #samples [[46 46] [33 33] [13 13] ... [ 6  6] [11 11] [11 11]]
        
        #output = butter_bandpass_filter(samples, 20, 1500, sample_rate) #음원 주파수 분리 코드
       
        wavfile.write(dst2, sample_rate, samples.astype(np.int16))
        
        #print(type(output))
        #print(type(samples))
        
        #ver 12.13 주파수 정규화 생략  
        #--------------------------norm2 까지 생성------------------------------------
        
    for path in paths:
        dst = os.path.join(os.getcwd(), args.p, path.split(args.path)[-1][1:])
        dst2 = os.path.join(os.getcwd(), 'norm', path.split(args.path)[-1][1:])
        path = os.path.join(os.getcwd(), 'norm2', path.split(args.path)[-1][1:])
        cnt += 1
        print(cnt, '/', file_num, path)
        sample_rate, samples = wavfile.read(path)
        
        
        
        #https://wdprogrammer.tistory.com/43
        
        #VAD 기본설정
        vad = webrtcvad.Vad()
        vad.set_mode(1)
        # 10, 20, or 30
        frame_duration = 30 # ms
        
        
        
        frames = frame_generator(frame_duration, samples, sample_rate)
        flag = True
        for i, frame in enumerate(frames):
            if vad.is_speech(frame.bytes, sample_rate):
                if flag:
                    start_idx = i
                    flag = False
                else:
                    end_idx = i
        start_idx -= 1
        end_idx += 1
     
        if start_idx <= 0:
            audio_start_frame = 0
        else:
            audio_start_frame = int(start_idx/100.0*sample_rate*2*3) #sample_rate == 16000
            
        
        if end_idx >= len(frames):
            audio_end_frame = len(samples)
        else:
            audio_end_frame = int(end_idx/100.0*sample_rate*2*3)
        audio_result_frames = audio_end_frame - audio_start_frame
        #print(audio_result_frames)
        
        if not os.path.isdir(args.p):
            os.mkdir(args.p)
            
            
            
        
        wav = wave.open(dst2, mode='rb')
        out_wav = wave.open(dst, mode='w')
        #dst==norm에 있는 것 가져다 씀
        
        channels = wav.getnchannels()
        sample_width = wav.getsampwidth()
        audio_frame_rate = wav.getframerate()
        
        out_wav.setnchannels(channels)
        out_wav.setsampwidth(sample_width)
        out_wav.setframerate(audio_frame_rate)

        out_wav.writeframes(compress_audio(wav, audio_start_frame, audio_end_frame, audio_result_frames))

        out_wav.close()
        
        #print(dst)
        
        silences, including_end = find_silences(dst)
        
        print(silences)
        #print(including_end)
        #silences = [(0.0, 0.3899375), (2.357875, 3.130125), (5.8864375, 6.3624375), (7.796125, 8.77425), (10.60975, 11.044125), (11.889875, 12.6058125)]
        
        
                
        if len(silences) == 0:#앞뒤로 무음 구간 아예 없는 경우임
            start_gap, end_gap = 0, 0
            
    
        else:
            if silences[0][0] == 0.0:
                start_gap = silences[0][1] - silences[0][0]
            else:
                start_gap = 0
            if including_end:
                end_gap = silences[-1][1] - silences[-1][0]
            else:
                end_gap = 0

        song = AudioSegment.from_wav(dst)
        
        if start_gap==0:
            seg = AudioSegment.silent(duration=300)
            start_gap += 0.300
            song = seg + song
        
        elif start_gap < 0.21:
            seg = AudioSegment.silent(duration=210)
            start_gap += 0.210
            song = seg + song
        
        if end_gap==0:
            seg = AudioSegment.silent(duration=300)
            end_gap += 0.300
            song = song+seg
            
        elif end_gap < 0.21:
            seg = AudioSegment.silent(duration=210)
            end_gap += 0.210
            song = song + seg
            
        
        song.export(dst, format="wav")
        
    
        print("start/end gap: ", round(start_gap, 2), round(end_gap, 2))
        print()
# Out:
# C:\Users\pc\Desktop\VAD연습\files\*.wav
# Num of file:  128
# Audio Normalization...
# 1 / 128 C:\Users\pc\Desktop\VAD연습\norm2\CN21RB001_CN0016_20210730.wav
# [(3.547625, 3.7966875), (8.3740625, 8.7)]
# start/end gap:  0.3 0.33
#
# 2 / 128 C:\Users\pc\Desktop\VAD연습\norm2\CN21RB001_CN0019_20210803.wav
# [(0.0, 0.269), (5.651375, 5.8646875)]
# start/end gap:  0.27 0.3
#
# 3 / 128 C:\Users\pc\Desktop\VAD연습\norm2\CN21RB001_CN0021_20210805.wav
# [(0.0, 0.2004375), (3.372625, 3.8166875), (8.0189375, 8.3)]
# start/end gap:  0.41 0.28
#
# 4 / 128 C:\Users\pc\Desktop\VAD연습\norm2\CN21RB001_CN0022_20210811.wav
# []
# start/end gap:  0.3 0.3
#
# 5 / 128 C:\Users\pc\Desktop\VAD연습\norm2\CN21RB001_CN0023_20210830.wav
# []
# start/end gap:  0.3 0.3
#
# 6 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EN31RA002_EN0008_20210802.wav
# [(0.0, 0.6115625), (2.00675, 2.243375), (6.699375, 6.97575), (8.6338125, 9.16)]
# start/end gap:  0.61 0.53
#
# 7 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EN31RA002_EN0017_20210816.wav
# [(0.0, 0.513875), (1.31725, 1.5774375), (2.59875, 3.4490625), (6.279, 6.73825), (9.960875, 10.8681875), (11.717875, 12.347625), (14.506875, 14.94)]
# start/end gap:  0.51 0.43
#
# 8 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EN31RA003_EN0006_20210811.wav
# [(0.0, 0.5493125), (1.5379375, 1.7856875), (3.3194375, 3.8616875), (5.3749375, 5.9049375), (6.1156875, 6.437875), (6.889, 7.1753125), (7.7030625, 8.3384375), (9.03125, 9.26275), (9.8425, 10.641875), (10.7839375, 11.091625), (12.703625, 12.997875), (13.4115, 13.871625), (14.068625, 14.3995), (14.851625, 15.503625), (16.1551875, 16.45525), (17.2346875, 17.518875), (17.652125, 18.1588125), (18.947875, 19.448875), (21.4730625, 21.9)]
# start/end gap:  0.55 0.43
#
# 9 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EN31RA003_EN0008_20210802.wav
# [(0.0, 0.438875), (2.23725, 2.650875), (3.2610625, 3.50575), (4.1366875, 4.3948125), (4.946, 5.3995), (6.2899375, 6.8655), (7.7251875, 8.2873125), (9.017375, 9.538875), (10.1625625, 10.518), (12.015875, 12.4303125), (16.1901875, 16.56)]
# start/end gap:  0.44 0.37
#
# 10 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EN31RA003_EN0017_20210816.wav
# [(0.0, 0.78), (2.1238125, 2.5508125), (3.3005, 3.6274375), (4.29375, 4.6585), (5.36, 5.956125), (6.5535, 6.884125), (8.050375, 8.640375), (9.8430625, 10.3528125), (11.2319375, 11.541375), (12.310875, 12.616625), (14.0774375, 14.7553125), (15.8975, 16.1508125), (17.898375, 18.146875), (19.773875, 20.536)]
# start/end gap:  0.78 0.76
#
# 11 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EN31RA004_EN0006_20210811.wav
# [(0.0, 0.628625), (3.125875, 3.4235625), (3.7136875, 3.9388125), (4.88225, 5.1124375), (5.3254375, 6.147875), (6.74225, 6.9784375), (7.54925, 7.7729375), (9.4118125, 9.6669375), (10.9398125, 11.6224375), (12.0036875, 12.2383125), (13.49775, 14.585625), (15.081125, 15.5898125), (16.652, 17.2886875), (17.8054375, 18.027375), (20.325, 20.736)]
# start/end gap:  0.63 0.41
#
# 12 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0123_20210818.wav
# [(2.817375, 3.2570625), (5.6954375, 6.063875)]
# start/end gap:  0.3 0.3
#
# 13 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0127_20210804.wav
# [(0.0, 0.353125), (3.36425, 3.7274375), (7.03975, 7.5048125), (11.1093125, 11.46)]
# start/end gap:  0.35 0.35
#
# 14 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0128_20210825.wav
# [(0.0, 0.513125), (2.941125, 3.462125), (5.81775, 6.26825), (7.9471875, 8.2859375), (10.3365625, 10.68)]
# start/end gap:  0.51 0.34
#
# 15 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0136_20210802.wav
# [(0.0, 0.89525), (2.204625, 2.48675), (3.6951875, 4.1694375), (6.715375, 6.9309375), (6.937125, 7.414125), (12.5204375, 13.24)]
# start/end gap:  0.9 0.72
#
# 16 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0137_20210818.wav
# [(0.0, 0.2098125), (2.7421875, 3.333625), (5.657, 6.4305), (10.56975, 10.92)]
# start/end gap:  0.42 0.35
#
# 17 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0139_20210818.wav
# [(0.0, 0.9430625), (1.40225, 1.6295), (4.0878125, 4.5365625), (7.85625, 8.104), (10.2296875, 10.4431875), (10.6538125, 10.8855), (11.350625, 11.82)]
# start/end gap:  0.94 0.47
#
# 18 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0145_20210831.wav
# [(0.0, 0.5928125), (3.57025, 4.1511875), (7.132625, 7.36325), (11.882125, 12.3858125), (13.19875, 13.56)]
# start/end gap:  0.59 0.36
#
# 19 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0150_20210808.wav
# [(0.0, 0.357625), (2.9079375, 3.15575), (3.368875, 3.88375), (6.311875, 6.8429375), (10.813125, 11.32)]
# start/end gap:  0.36 0.51
#
# 20 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0154_20210828.wav
# [(3.043875, 3.527), (5.9225, 6.4575)]
# start/end gap:  0.3 0.3
#
# 21 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0165_20210802.wav
# [(0.0, 0.6923125), (1.9269375, 2.488125), (3.600375, 4.3776875), (5.836875, 6.163), (7.092875, 7.6295), (9.28325, 9.7279375), (11.6555, 12.0599375)]
# start/end gap:  0.69 0.4
#
# 22 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0174_20210829.wav
# [(0.0, 0.3445), (1.9090625, 2.73625), (3.5881875, 3.8233125), (4.010375, 4.5330625), (6.850875, 7.7110625), (8.2695, 8.5236875), (10.5346875, 10.8419375), (12.571, 12.82)]
# start/end gap:  0.34 0.25
#
# 23 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0175_20210828.wav
# [(0.0, 0.4225), (4.068375, 4.4943125), (7.10925, 7.312), (7.3203125, 7.612125), (12.8270625, 13.08)]
# start/end gap:  0.42 0.25
#
# 24 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0180_20210808.wav
# [(0.0, 0.674125), (1.014125, 1.22525), (2.146375, 2.6628125), (3.827625, 4.3960625), (5.878875, 6.2840625), (7.234125, 7.9868125), (8.5329375, 8.759875), (9.9983125, 10.56925), (12.5951875, 12.96)]
# start/end gap:  0.67 0.36
#
# 25 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0184_20210818.wav
# [(0.0, 0.295125), (2.9366875, 3.137875), (9.5416875, 9.82)]
# start/end gap:  0.3 0.28
#
# 26 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0185_20210829.wav
# [(0.0, 0.584), (3.6221875, 3.8843125), (6.420375, 6.808625), (8.5645, 8.8985625), (10.9691875, 11.34)]
# start/end gap:  0.58 0.37
#
# 27 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0205_20210812.wav
# [(0.3391875, 0.6716875), (3.0231875, 3.2446875), (3.5226875, 4.242), (6.638625, 7.3545), (10.667125, 10.92)]
# start/end gap:  0.3 0.25
#
# 28 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0207_20210831.wav
# []
# start/end gap:  0.3 0.3
#
# 29 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0208_20210826.wav
# [(0.0, 0.3679375), (1.807125, 2.062125), (2.75675, 3.1020625), (3.2691875, 3.8615625), (6.3006875, 6.7490625), (11.4545, 11.7773125)]
# start/end gap:  0.37 0.32
#
# 30 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0209_20210831.wav
# [(0.0, 0.34425), (2.7109375, 2.953375), (3.18225, 3.7570625), (9.573875, 9.96)]
# start/end gap:  0.34 0.39
#
# 31 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0223_20210802.wav
# [(0.0, 0.530875), (2.3571875, 2.7485), (3.9726875, 4.32025), (6.883625, 7.406375), (11.2199375, 11.5341875), (12.19625, 12.592)]
# start/end gap:  0.53 0.4
#
# 32 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0234_20210816.wav
# [(3.492125, 3.9158125), (5.485125, 5.7149375), (6.8056875, 7.2099375), (7.6795, 7.956375), (9.632, 9.965), (11.6525625, 12.33575), (13.14125, 13.46)]
# start/end gap:  0.3 0.32
#
# 33 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0252_20210809.wav
# [(2.045875, 2.5735625), (3.8684375, 4.33775), (7.4079375, 7.9819375), (8.7098125, 8.9376875), (10.6089375, 11.0193125), (12.9491875, 13.2703125), (14.15375, 14.52)]
# start/end gap:  0.3 0.37
#
# 34 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0264_20210823.wav
# [(0.0, 0.5336875), (0.7016875, 1.17325), (1.2429375, 9.742625)]
# start/end gap:  0.53 8.5
#
# 35 / 128 C:\Users\pc\Desktop\VAD연습\norm2\EX51RA001_EX0275_20210824.wav
# [(0.0, 0.62825), (2.4985625, 3.06575), (4.3499375, 4.7130625), (4.7233125, 5.126125), (7.4330625, 8.0135), (11.5605625, 11.94)]
# start/end gap:  0.63 0.38
#
# 36 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0011_20210801.wav
# []
# start/end gap:  0.3 0.3
#
# 37 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0043_20210827.wav
# [(0.0, 0.699625), (2.2436875, 2.546625), (6.779875, 7.4455), (12.477375, 12.80425), (14.293125, 14.64)]
# start/end gap:  0.7 0.35
#
# 38 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0045_20210804.wav
# [(0.0, 0.358625), (0.3668125, 0.6035), (1.4325625, 1.8196875), (4.292625, 4.7488125), (6.481625, 6.9053125), (7.86175, 8.194125), (12.58275, 12.96)]
# start/end gap:  0.36 0.38
#
# 39 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0046_20210830.wav
# [(0.0, 0.8713125), (11.5500625, 11.82)]
# start/end gap:  0.87 0.27
#
# 40 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0048_20210810.wav
# [(0.0, 0.57625), (1.3174375, 1.6490625)]
# start/end gap:  0.58 0.3
#
# 41 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0050_20210731.wav
# []
# start/end gap:  0.3 0.3
#
# 42 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0054_20210807.wav
# [(1.1364375, 1.412875), (2.412625, 2.651), (3.5578125, 4.218625), (7.01375, 7.708625), (8.6013125, 8.96525), (9.60775, 10.01525), (11.227875, 11.4595625), (12.0794375, 12.588375), (14.526625, 15.024)]
# start/end gap:  0.3 0.5
#
# 43 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0060_20210811.wav
# [(0.0, 0.325625), (4.4448125, 4.792625), (8.8701875, 9.18)]
# start/end gap:  0.33 0.31
#
# 44 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0066_20210818.wav
# [(0.0, 0.3233125), (3.471375, 3.7503125), (5.7401875, 5.948375), (7.0960625, 7.315125)]
# start/end gap:  0.32 0.3
#
# 45 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0083_20210803.wav
# [(0.0, 0.801375), (4.1529375, 4.950875), (6.4944375, 6.947625), (8.3316875, 8.6110625), (9.779375, 10.4768125), (11.4218125, 11.94675), (12.423875, 12.96875), (14.1435, 14.5863125), (15.611125, 15.9684375), (17.369, 18.1353125), (19.0489375, 19.5149375), (20.186875, 20.43575), (20.7304375, 20.960375), (21.1478125, 21.66)]
# start/end gap:  0.8 0.51
#
# 46 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0084_20210825.wav
# [(0.0, 0.9816875), (1.64925, 2.1469375), (4.7123125, 5.6055625), (7.32725, 8.1730625), (9.131625, 9.5085), (10.980875, 11.5224375), (14.6000625, 15.0)]
# start/end gap:  0.98 0.4
#
# 47 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0086_20210818.wav
# [(0.16675, 0.805625), (2.9775, 3.4124375), (6.1806875, 6.6876875), (12.148375, 12.48)]
# start/end gap:  0.3 0.33
#
# 48 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0090_20210824.wav
# [(0.0, 0.2095625), (5.916625, 6.2594375), (8.9066875, 9.13375)]
# start/end gap:  0.42 0.3
#
# 49 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0101_20210829.wav
# [(0.0, 0.5069375), (1.1776875, 1.650125), (3.260125, 3.7291875), (4.803875, 5.7233125), (7.7495625, 8.2545625), (9.4273125, 9.806125), (11.59675, 12.0755625), (13.45025, 13.887125), (14.59825, 15.05775), (16.62375, 17.0053125)]
# start/end gap:  0.51 0.38
#
# 50 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0111_20210828.wav
# [(5.8365625, 6.35725), (9.9744375, 10.1850625), (10.2898125, 10.540625), (12.1925625, 12.54)]
# start/end gap:  0.3 0.35
#
# 51 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0118_20210814.wav
# [(5.45025, 5.661), (10.1355625, 10.5364375)]
# start/end gap:  0.3 0.3
#
# 52 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA001_TH0119_20210807.wav
# []
# start/end gap:  0.3 0.3
#
# 53 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA002_TH0002_20210831.wav
# [(0.0, 0.234125), (4.0570625, 4.4836875), (6.573, 6.9031875), (8.083625, 8.3755), (11.759, 12.0995), (12.951875, 13.3195625)]
# start/end gap:  0.23 0.3
#
# 54 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA002_TH0010_20210816.wav
# [(0.0, 0.386375), (1.8546875, 2.186), (2.62275, 2.9054375), (5.013625, 5.604125), (7.535375, 7.7853125), (8.001, 8.6105), (9.383125, 9.9319375), (10.02575, 10.2396875), (11.5353125, 11.823), (11.8965625, 12.32)]
# start/end gap:  0.39 0.42
#
# 55 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA002_TH0011_20210801.wav
# []
# start/end gap:  0.3 0.3
#
# 56 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA002_TH0042_20210813.wav
# [(0.0, 0.9993125), (6.9568125, 7.34775), (8.80075, 9.16475), (10.059, 10.44)]
# start/end gap:  1.0 0.38
#
# 57 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA002_TH0043_20210827.wav
# [(0.1715625, 0.863), (2.448, 2.884875), (4.2850625, 4.6190625), (7.4858125, 7.9145), (10.797125, 11.2515), (13.6838125, 14.04)]
# start/end gap:  0.3 0.36
#
# 58 / 128 C:\Users\pc\Desktop\VAD연습\norm2\TH31RA002_TH0045_20210804.wav
# [(0.2451875, 0.62575), (11.563, 11.88)]
# start/end gap:  0.3 0.32
#
# 59 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0024_20210830.wav
# [(5.048125, 5.41725), (7.1385, 7.5073125), (9.728375, 10.188125), (11.4855625, 11.776)]
# start/end gap:  0.3 0.29
#
# 60 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0032_20210812.wav
# [(1.139375, 1.59025), (5.4965, 5.88675), (7.443125, 7.956875), (10.52425, 11.124375)]
# start/end gap:  0.3 0.3
#
# 61 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0034_20210816.wav
# []
# start/end gap:  0.3 0.3
#
# 62 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0037_20210730.wav
# [(0.4175, 1.0285), (6.625125, 6.8494375), (8.4800625, 8.8744375), (10.498375, 10.716875), (12.035, 12.3880625)]
# start/end gap:  0.3 0.3
#
# 63 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0041_20210827.wav
# []
# start/end gap:  0.3 0.3
#
# 64 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0044_20210825.wav
# [(0.0, 0.3415625), (4.8680625, 5.3386875), (6.2314375, 6.432625), (6.592125, 6.97425), (8.350875, 8.6685), (10.8933125, 11.12)]
# start/end gap:  0.34 0.23
#
# 65 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0045_20210731.wav
# []
# start/end gap:  0.3 0.3
#
# 66 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0046_20210804.wav
# [(0.0, 0.4456875), (0.455375, 0.879375), (5.199375, 5.8274375), (8.706, 8.9605625), (11.1731875, 11.52)]
# start/end gap:  0.45 0.35
#
# 67 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0052_20210830.wav
# [(5.9404375, 6.198875), (7.7653125, 7.9684375), (8.7765625, 9.0545625), (12.9399375, 13.28)]
# start/end gap:  0.3 0.34
#
# 68 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0058_20210819.wav
# [(0.07075, 0.385375), (2.3833125, 3.0094375), (5.9169375, 6.3004375), (7.8268125, 8.1356875), (8.15475, 8.7694375), (12.011, 12.547625)]
# start/end gap:  0.3 0.3
#
# 69 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0064_20210819.wav
# [(0.0, 0.2898125), (0.35175, 0.6306875), (2.4824375, 3.0314375), (6.392125, 6.607), (8.646, 8.8488125), (9.962625, 10.2984375), (12.52275, 12.8180625), (14.0573125, 14.36)]
# start/end gap:  0.29 0.3
#
# 70 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0067_20210808.wav
# []
# start/end gap:  0.3 0.3
#
# 71 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0075_20210827.wav
# [(0.0, 0.2651875), (1.3663125, 1.5848125), (5.172875, 5.5479375), (6.9574375, 7.5020625), (9.0508125, 9.420875), (10.20475, 10.5253125), (11.6976875, 11.98)]
# start/end gap:  0.27 0.28
#
# 72 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0076_20210801.wav
# [(0.0, 0.5174375), (1.606875, 1.925875), (5.802125, 6.1705), (7.6531875, 8.5674375), (9.400125, 9.8943125), (10.7894375, 11.1095), (12.082875, 12.6093125), (14.31425, 14.7)]
# start/end gap:  0.52 0.39
#
# 73 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0090_20210818.wav
# [(0.0, 0.588875), (5.068875, 5.446), (7.029875, 7.4854375), (9.120375, 9.3405), (11.12775, 11.474875), (14.222875, 14.58)]
# start/end gap:  0.59 0.36
#
# 74 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0097_20210817.wav
# [(0.0, 0.7980625), (2.323, 2.54275), (4.81625, 5.0409375), (5.436125, 6.015125), (6.9695, 7.225), (7.2306875, 7.51275), (7.66775, 7.9704375), (7.979, 8.2255625), (8.4530625, 8.8605625), (8.86675, 9.0776875), (9.0884375, 9.7618125), (11.206, 11.5424375), (11.922, 12.42)]
# start/end gap:  0.8 0.5
#
# 75 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0102_20210811.wav
# [(0.0, 0.53775), (1.915875, 2.1840625), (2.3424375, 2.7545625), (4.1860625, 4.83475), (4.9844375, 5.4383125), (5.9630625, 6.17875), (6.885, 7.278), (7.3769375, 7.58325), (7.993875, 8.3755625), (8.50525, 8.96875), (9.576, 10.4051875), (10.739125, 11.1795625), (11.214875, 11.4645)]
# start/end gap:  0.54 0.3
#
# 76 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0107_20210902.wav
# [(0.0, 0.2996875), (3.85625, 4.1495625), (5.6405, 6.147), (7.6668125, 8.1118125), (9.0659375, 9.3061875), (9.8740625, 10.4680625), (10.8206875, 11.0289375)]
# start/end gap:  0.3 0.3
#
# 77 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0108_20210830.wav
# [(1.60075, 1.80125), (5.6425625, 5.9903125), (9.708625, 9.996), (12.7948125, 13.14)]
# start/end gap:  0.3 0.35
#
# 78 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0112_20210822.wav
# [(1.321875, 1.639375), (2.761625, 3.112375), (6.2975, 6.7943125), (7.68775, 8.0665), (9.1779375, 9.7354375), (11.201625, 11.468625)]
# start/end gap:  0.3 0.3
#
# 79 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0115_20210828.wav
# [(0.0, 0.2079375), (0.9853125, 1.5316875), (2.372875, 2.890625), (5.1874375, 5.7040625), (6.4455, 6.6604375), (6.9305625, 7.5599375), (9.7990625, 10.2399375)]
# start/end gap:  0.42 0.3
#
# 80 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0130_20210803.wav
# [(0.0, 0.720375), (2.2233125, 2.52625), (2.57575, 2.953), (4.7604375, 5.184875), (5.2971875, 5.51075), (5.834875, 6.903), (7.8668125, 8.1704375), (8.2964375, 8.9385), (10.21975, 10.4754375), (10.66275, 11.088625), (11.8665, 12.2930625), (13.1654375, 14.0570625), (14.560375, 15.06)]
# start/end gap:  0.72 0.5
#
# 81 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0146_20210731.wav
# [(0.0, 0.5164375), (6.9055625, 7.1255), (7.4159375, 7.7725625), (10.7218125, 10.9524375), (11.5084375, 11.8029375)]
# start/end gap:  0.52 0.3
#
# 82 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0150_20210730.wav
# [(8.77375, 9.05425)]
# start/end gap:  0.3 0.3
#
# 83 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0155_20210830.wav
# [(1.5274375, 1.933), (6.38275, 6.77975), (7.961125, 8.16975), (8.5346875, 9.0511875), (10.789125, 11.0118125), (12.3265, 12.6098125), (14.413125, 14.68)]
# start/end gap:  0.3 0.27
#
# 84 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0156_20210804.wav
# [(0.0, 0.4913125), (2.5041875, 2.918375), (5.3390625, 5.9950625), (7.2754375, 7.6633125), (9.085375, 9.448125)]
# start/end gap:  0.49 0.3
#
# 85 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0173_20210828.wav
# [(0.0, 0.2925), (1.2410625, 1.763375), (2.0500625, 2.26325), (4.66, 5.038625), (6.5736875, 7.022125), (8.848375, 9.2149375), (11.1955, 11.7455625)]
# start/end gap:  0.29 0.3
#
# 86 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0180_20210818.wav
# [(0.0, 0.4691875), (5.6321875, 6.3380625), (8.1980625, 8.4976875), (9.6069375, 9.9689375), (11.89025, 12.315375)]
# start/end gap:  0.47 0.3
#
# 87 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0181_20210812.wav
# [(0.0, 0.47825), (10.19525, 10.4269375)]
# start/end gap:  0.48 0.3
#
# 88 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0184_20210730.wav
# []
# start/end gap:  0.3 0.3
#
# 89 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0195_20210831.wav
# [(9.262, 9.8465), (12.204625, 12.7765)]
# start/end gap:  0.3 0.3
#
# 90 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0222_20210827.wav
# [(0.0, 0.341), (0.5520625, 0.784625), (7.9568125, 8.17025), (10.678375, 10.941125), (12.1686875, 12.525125), (14.090875, 14.46)]
# start/end gap:  0.34 0.37
#
# 91 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0225_20210830.wav
# [(0.0, 0.3093125), (0.326125, 0.8796875), (5.199375, 5.9804375), (7.0985625, 7.4884375), (9.1204375, 9.533), (11.2489375, 11.64)]
# start/end gap:  0.31 0.39
#
# 92 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0233_20210820.wav
# [(0.182625, 0.53425), (6.088125, 6.5366875), (8.4135625, 9.0224375), (11.0435625, 11.461875), (12.67225, 13.3846875), (14.7713125, 15.204)]
# start/end gap:  0.3 0.43
#
# 93 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0243_20210827.wav
# [(0.0, 0.324875), (0.333375, 0.88275), (5.52175, 5.827375), (7.1063125, 7.4968125), (9.82025, 10.2910625), (11.4205, 11.76)]
# start/end gap:  0.32 0.34
#
# 94 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0254_20210827.wav
# [(0.0, 0.3640625), (6.5084375, 6.9891875), (8.029, 8.2459375), (8.5905625, 9.1421875), (10.8371875, 11.3016875), (11.6738125, 11.875125), (12.3920625, 12.8338125), (13.5095, 13.7139375), (14.1829375, 14.406625)]
# start/end gap:  0.36 0.22
#
# 95 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0255_20210826.wav
# [(0.0, 0.7479375), (1.7210625, 2.1130625), (3.1365625, 3.3551875), (5.812875, 6.348), (7.26025, 7.52), (7.733625, 8.23625), (9.6620625, 10.397125), (11.1876875, 11.413125), (12.6366875, 13.08)]
# start/end gap:  0.75 0.44
#
# 96 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0257_20210806.wav
# [(0.0, 1.9710625), (2.6029375, 2.839625), (3.017, 3.6568125), (4.6621875, 4.961), (5.892625, 6.195), (8.8385625, 9.4245), (10.8064375, 11.087125), (11.2939375, 11.6635625), (13.0855, 13.369625), (14.024625, 14.3500625), (16.0226875, 16.44)]
# start/end gap:  1.97 0.42
#
# 97 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0259_20210814.wav
# [(0.0846875, 0.5055625), (3.0713125, 3.629125), (6.4845, 6.8124375), (6.8705, 7.2010625), (8.384625, 8.825125), (10.0481875, 10.5551875)]
# start/end gap:  0.3 0.3
#
# 98 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0271_20210831.wav
# [(0.0, 0.439375), (3.8929375, 4.30175), (8.21675, 8.5075), (11.39275, 11.61975), (12.1838125, 12.4125), (14.835, 15.159125)]
# start/end gap:  0.44 0.3
#
# 99 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0277_20210828.wav
# [(0.238125, 0.6500625), (2.792, 3.2096875), (5.811375, 6.0269375), (7.57925, 7.833), (8.051375, 8.5775), (10.228125, 10.6533125), (13.0646875, 13.44)]
# start/end gap:  0.3 0.38
#
# 100 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0278_20210826.wav
# [(0.0, 0.844875), (1.3854375, 1.7275), (3.697, 4.01975), (6.8883125, 7.434625), (8.9680625, 9.443875), (10.8913125, 11.36775), (13.720875, 14.08325), (14.2930625, 14.78)]
# start/end gap:  0.84 0.49
#
# 101 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0292_20210831.wav
# [(0.0, 0.7385625), (6.1193125, 6.5645), (7.9568125, 8.273625), (12.3166875, 12.66)]
# start/end gap:  0.74 0.34
#
# 102 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0298_20210829.wav
# [(0.0, 0.6860625), (0.8600625, 1.077625), (1.1038125, 2.8260625), (3.0909375, 3.4306875), (3.50575, 4.1284375), (4.143375, 5.2226875), (5.366375, 6.1808125), (6.1985625, 6.4643125), (6.5683125, 7.308625), (7.4756875, 8.361), (8.366625, 8.652875), (8.7254375, 9.734125), (9.7418125, 10.608375), (10.658125, 11.5325), (11.6091875, 12.6308125), (12.7271875, 12.96)]
# start/end gap:  0.69 0.23
#
# 103 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0302_20210901.wav
# [(0.039125, 0.5), (1.3725625, 1.658875), (2.578875, 2.8496875), (8.073, 8.5715625), (10.627375, 11.0271875), (12.1301875, 12.3381875), (14.1009375, 14.4530625)]
# start/end gap:  0.3 0.3
#
# 104 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0303_20210830.wav
# [(0.0, 0.82725), (2.1059375, 2.417625), (3.1568125, 3.4214375), (5.877625, 6.38475), (6.9226875, 7.2905), (8.05975, 8.376125), (9.6453125, 10.0093125), (10.950125, 11.3309375), (12.583125, 12.96)]
# start/end gap:  0.83 0.38
#
# 105 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB001_VN0316_20210902.wav
# [(0.0, 0.3648125), (1.503125, 1.920125), (3.6776875, 3.9104375), (6.3659375, 6.667875), (8.268625, 8.829), (9.6908125, 9.9388125), (10.9210625, 11.155125), (12.3060625, 12.9789375)]
# start/end gap:  0.36 0.3
#
# 106 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0005_20210812.wav
# [(2.5466875, 2.91075), (4.7386875, 5.2856875), (5.7599375, 6.196625), (7.1963125, 7.5160625), (9.178625, 9.5725625), (11.0008125, 11.34)]
# start/end gap:  0.3 0.34
#
# 107 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0021_20210825.wav
# [(0.0, 0.7884375), (3.6619375, 4.0113125), (5.8928125, 6.268), (7.9614375, 8.2930625), (10.086, 10.5525625), (11.9405625, 12.44)]
# start/end gap:  0.79 0.5
#
# 108 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0023_20210804.wav
# [(0.0, 0.6949375), (1.55375, 1.80225), (3.60575, 3.9496875), (5.7863125, 6.176875), (11.3016875, 11.76)]
# start/end gap:  0.69 0.46
#
# 109 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0032_20210812.wav
# [(2.4004375, 2.77), (4.716875, 5.0945625), (9.59425, 10.0)]
# start/end gap:  0.3 0.41
#
# 110 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0034_20210816.wav
# []
# start/end gap:  0.3 0.3
#
# 111 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0037_20210730.wav
# [(10.5848125, 10.832)]
# start/end gap:  0.3 0.25
#
# 112 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0041_20210827.wav
# []
# start/end gap:  0.3 0.3
#
# 113 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0044_20210825.wav
# [(0.0, 0.369375), (4.534, 4.872125)]
# start/end gap:  0.37 0.3
#
# 114 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0045_20210731.wav
# []
# start/end gap:  0.3 0.3
#
# 115 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0046_20210804.wav
# [(1.031875, 1.3249375), (6.7184375, 6.9304375), (8.0335, 8.338375), (9.4743125, 9.84)]
# start/end gap:  0.3 0.37
#
# 116 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0052_20210801.wav
# [(0.0, 0.2283125)]
# start/end gap:  0.23 0.3
#
# 117 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0058_20210819.wav
# [(6.118375, 6.47175), (7.3544375, 7.799)]
# start/end gap:  0.3 0.3
#
# 118 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0061_20210826.wav
# [(0.9684375, 1.2003125)]
# start/end gap:  0.3 0.3
#
# 119 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0064_20210819.wav
# [(0.0, 0.473125), (4.5183125, 4.7641875)]
# start/end gap:  0.47 0.3
#
# 120 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0075_20210827.wav
# [(0.0, 0.2163125), (2.5809375, 2.814875), (4.332875, 4.611125), (5.13725, 5.341875)]
# start/end gap:  0.22 0.3
#
# 121 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0076_20210801.wav
# [(0.0, 0.8051875), (5.872, 6.674625), (9.7439375, 10.14)]
# start/end gap:  0.81 0.4
#
# 122 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0090_20210818.wav
# [(0.0, 0.4279375), (3.3014375, 3.750125), (5.608125, 6.033375), (10.40825, 10.619375), (11.1565, 11.52)]
# start/end gap:  0.43 0.36
#
# 123 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0097_20210817.wav
# [(0.0, 0.50025), (1.188875, 1.5130625), (1.973625, 2.226), (2.6735, 2.9135), (3.035375, 3.56375), (4.2505625, 4.563625), (5.0349375, 5.563375), (6.112375, 6.5031875), (6.6330625, 6.883625), (6.9971875, 7.4089375), (8.0094375, 8.4723125), (9.2565, 9.55), (10.017, 10.2785), (10.429, 11.212)]
# start/end gap:  0.5 0.78
#
# 124 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0102_20210811.wav
# [(0.0, 0.5680625), (1.1388125, 1.4130625), (2.489625, 2.8989375), (4.5139375, 5.00675), (6.763375, 7.072125), (7.803375, 8.1700625), (8.57075, 8.995875), (9.083, 9.54)]
# start/end gap:  0.57 0.46
#
# 125 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0107_20210902.wav
# [(0.0, 0.206125), (2.677375, 3.0518125), (5.3415, 5.7455), (7.641125, 8.2096875), (10.862, 11.26)]
# start/end gap:  0.42 0.4
#
# 126 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0108_20210830.wav
# [(2.7164375, 3.0970625), (4.964875, 5.248125), (6.8171875, 7.181875), (10.389375, 10.74)]
# start/end gap:  0.3 0.35
#
# 127 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0111_20210821.wav
# [(0.0, 0.206375), (3.03575, 3.3314375), (5.1715625, 5.4734375), (9.5398125, 9.82)]
# start/end gap:  0.42 0.28
#
# 128 / 128 C:\Users\pc\Desktop\VAD연습\norm2\VN41RB002_VN0112_20210822.wav
# [(5.030125, 5.547625), (9.2570625, 9.686375), (11.0595, 11.38)]
# start/end gap:  0.3 0.32
